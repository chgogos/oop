// %%
#include <iostream>

// %%
int fun(int x){
    return x + 1;
}

// %%
std::cout << fun(10);
// Out:
// 11

// %%
#include <algorithm>
#include <ranges>

int a[] ={1,2,3};
std::for_each(std::begin(a), std::end(a), [](int x){std::cout << x << std::endl;})
